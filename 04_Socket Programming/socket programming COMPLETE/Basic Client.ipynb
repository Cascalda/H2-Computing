# %%
"""This is a general illustration, as such the function do not work as it is"""

### BTW, just rename the variables as required...
#...these variables are named to make sense for general purpose

# Receiving message function
def receive_msg(my_socket):
    recevied_msg = ""
    while "\n" not in recevied_msg:
        # 1024 is the buffer size, which is a small power of 2
        recevied_msg += my_socket.recv(1024).decode()
    return received_msg.strip("\n")

# Menu, maybe even validation required
def menu():
    pass

    # start from here ------------
    display = """
    Title
    1. Kermit
    2. Kermitted
    3. Kermittance
    4. Quit
    """
    print(display)
    option = int(input("Please input yor option: "))
    
    done = False
    while not done:
        if option == 1:
            client_msg = input("Please input your message: ")
            # There may be a starting word, also remember to end on \n
            msg_to_send = f"STARTINGWORD {client_msg}\n" # This is f-string formatting
            client_socket.send(msg_to_send.encode())
            
            received = receive_msg(client_socket)
            # ...
            pass
            
        elif option == 2:
            # ...
            pass
        
        elif option == 3:
            # ...
            pass
        
        else:
            # ...
            done = True
            
#-------------------------------------------------------------------------------------------           
import socket

# Initiate the client, the AF_INET and SOCK_STREAM is default so dont worry
client_socket = socket.socket()

address = 'localhost' # this is the same as 127.0.0.1, it is computer connecting with itself
port = 12345 # whatever the address

print(">>> Waiting for connection from server...")
client_socket.connect((address, port))
print(">>> Connected to server...")

menu()

# Close the socket
print(">>> Closing socket...")
client_socket.close() 
print(">>> Socket closed")
# Out:
# >>> Waiting for connection from server...
# >>> Connected to server...
#
#     Title
#     1. Kermit
#     2. Kermitted
#     3. Kermittance
#     4. Quit
#
# Please input yor option: 4
# >>> Closing socket...
# >>> Socket closed
